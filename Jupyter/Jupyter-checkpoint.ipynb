# %% [markdown]
# # Jupyter Notebook
#
# ## Description
# Jupyter Notebook is an open-source web application that allws you to create and share documents that contain live code, text. It is widely used in data scince, machine learning, and scientific computing for data cleaning and transformation, numerical simulation, statistical modeling, data visualization, machine learning, and much more.
#
# ## Features
# - Interactive code execution
# - Markdown support for rich text
# - Inline visualizations
# - Support for multiple programming languages via kernals (e.g Python, R, Julia)
# - Extensions and plugins for enhanced functionality
# - Export to various formats (HTML, PDF, etc.)
#
# ## Access
# ### Installation
# You can install Jupyter Notebook using pip:

# %%
pip install notebook

# %% [markdown]
# Or, if you are using Anaconda, Jupyter Notebook comes pre-installed:

# %%
conda indysll jupyter

# %% [markdown]
# ### Launching Jupyter Notebook
# To start the jupyter Notebook server, run:

# %%
jupyter notebook

# %% [markdown]
# This will open the Jupyter Notebook interface in you web browser.

# %% [markdown]
# ## Website
# https://jupyter.org/

# %% [markdown]
# ## Using Markdown
# You can write descriptive text using Markdown:

# %% [raw]
# # This is a heading

# %% [markdown]
# # This is a heading

# %% [raw]
# ## This is a subheading

# %% [markdown]
# ## This is a subheading

# %% [raw]
# - This is a bullet point

# %% [markdown]
# - This is a bullet point

# %% [raw]
# 1. This is a numbered list

# %% [markdown]
# 1. This is a numbered list

# %% [raw]
# **This is text is bold**

# %% [markdown]
# **This is text is bold**

# %% [raw]
# *This text is italicized*

# %% [markdown]
# *This text is italicized*

# %% [markdown]
# ## Exsampels Usage
# ### Creating a Notebook
# 1. Open the Jupyter Notebook interface in your web browser.
# 2. Click on new and select the desired kernel (e.g Python 3) to create a new notebook.
# 3. Write and execute code in the cells. For example:

# %%
import pandas as pd
from sklearn.datasets import load_iris

# Load the Iris dataset
iris = load_iris()
data = pd.DataFrame(iris.data, columns=iris.feature_names)
data['target'] = iris.target

# Display the first few rows of the dataset
data.head(100)
# Out:
#     sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)  \
# 0                 5.1               3.5                1.4               0.2
# 1                 4.9               3.0                1.4               0.2
# 2                 4.7               3.2                1.3               0.2
# 3                 4.6               3.1                1.5               0.2
# 4                 5.0               3.6                1.4               0.2
# ..                ...               ...                ...               ...
# 95                5.7               3.0                4.2               1.2
# 96                5.7               2.9                4.2               1.3
# 97                6.2               2.9                4.3               1.3
# 98                5.1               2.5                3.0               1.1
# 99                5.7               2.8                4.1               1.3
#
#     target
# 0        0
# 1        0
# ...

# %%
from sklearn.model_selection import train_test_split
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import accuracy_score

# Split the dataset into training and testing sets
X = data.drop('target', axis=1)
y = data['target']
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

# Train the decision tree classifier
clf = DecisionTreeClassifier()
clf.fit(X_train, y_train)

# Make predictions on the test set
y_pred = clf.predict(X_test)

# Calculate the accuracy of the model
accuracy = accuracy_score(y_test, y_pred)
print(f"Model accuracy: {accuracy:.2f}")
# Out:
# Model accuracy: 1.00

# %%
from sklearn.tree import plot_tree
import matplotlib.pyplot as plt

# Plot the decision tree
plt.figure(figsize=(12,8))
plot_tree(clf, feature_names=iris.feature_names, class_names=iris.target_names, filled=True)
plt.show()
